# %% [markdown]
# # Threshold effects as I showed to Boris

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.09/03

# %%
# %%cpp
# .L ~/Tools/wavefitter/scripts/plot_whatever.C+

# %%
# %%cpp
# TCanvas *c1;

# %%
# %%cpp
# c1 = compare_whatever(9,
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/inverted.Deck.large.root",
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/inverted.Deck.thresholded.large.root",
#                       81,
#                       "h%d");
# if (c1) c1->Draw();

# %% [markdown]
# ## the high statistics results

# %%
# %%cpp
# c1 = compare_whatever(9,
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/try4.large/result.invert_matrix_non_symm.root",
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/try5.large/result.invert_matrix_non_symm.root",
#                       81,
#                       "h%d");
# if (c1) c1->Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# # Compare specific set of waves $0^{-+}$

# %% [markdown]
# Symmetrized thresholded vs not. first try (likely tr2)

# %%
# %%cpp
# c1 = compare_whatever({3,4,5,6,7},
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/inverted.Deck.large.root",
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/inverted.Deck.thresholded.large.root",
#                       "h%d");
# if (c1) c1->Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# Symmetrized thresholded vs not. first try (likely tries 4,5)

# %%
# %%cpp
# c1 = compare_whatever({3,4,5,6,7},
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/try4.large/result.invert_matrix_non_symm.root",
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/try5.large/result.invert_matrix_non_symm.root",
#                       "h%d");
# if (c1) c1->Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# ## compare results for try2 and try 3

# %%
# %%cpp
# c1 = compare_whatever({3,4,5,6,7},
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/inverted.Deck.large.root",
#                       "/mnt/data/compass/2008/Deck.88waves.linal.misha/try3.large/result.invert_matrix_symm.root",
#                       "h%d");
# if (c1) c1->Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

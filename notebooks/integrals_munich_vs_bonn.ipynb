# %% [markdown]
# ## Compare my integrals with Dima's/Stefan's

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.09/03

# %%
# %%cpp
# .L compare_integrals.C+

# %%
# %%cpp
# c1 = compare_integrals(9,
#                        "/mnt/data/compass/2008/Deck.88waves.linal.misha/try3.large/waves.calculate_phase_space_symm.root");
# if (c1) c1->Draw();
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.09/03

# %%
# %%cpp
# .L ../scripts/compare_deck_expansion_and_pure.C+

# %% [markdown]
# # Non-symmetrized amplitude
# ## Low $M_{3\pi}$ mass

# %%
# %%cpp
# TCanvas *c1;

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s1)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try6.large/result.invert_matrix.root.non_symm",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         70);
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
# %%cpp
# c1->Draw();

# %%
# %%cpp
# c1->SaveAs("/tmp/pipi.num.bin70.pdf");

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s3)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try4.large/result.invert_matrix_non_symm.root",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         80);
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
# %%cpp
# c1->Draw();

# %% [markdown]
# ## Low $M_{3\pi}$ mass

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s1)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try4.large/result.invert_matrix_non_symm.root",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         40);
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
# %%cpp
# c1->Draw();

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s1)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try6.large/result.invert_matrix.root.non_symm",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         35);
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
# %%cpp
# c1->Draw();

# %%
# %%cpp
# c1->SaveAs("/tmp/pipi.num.bin35.pdf");
# Out:
# Info in <TCanvas::Print>: pdf file /tmp/pipi.num.bin35.pdf has been created

# %% [markdown]
# ## Thresholded

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s1)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try8.large/result.invert_matrix.root.non_symm",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         35);

# %%
# %%cpp
# c1->Draw();

# %%
# %%cpp
# c1->SaveAs("/tmp/pipi.num.thresholded.bin35.pdf");

# %% [markdown]
# # Symmetrized amplitude

# %% [markdown]
# ## High mass

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s3)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try3.large/result.invert_matrix_symm.root",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         80, true);

# %%
# %%cpp
# c1->Draw();

# %% [markdown]
# ## Low mass

# %%
# %%cpp
# c1 = compare_deck_expansion_and_pure("sqrt(s3)",
#         "/mnt/data/compass/2008/Deck.88waves.linal.misha/try3.large/result.invert_matrix_symm.root",
#         "/mnt/data/compass/2008/phase_space_MC/direct_%d_large1e6.root",
#         40, true);

# %%
# %%cpp
# c1->Draw();
